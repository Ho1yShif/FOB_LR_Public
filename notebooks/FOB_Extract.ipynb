# %% [markdown]
# # Extracting FOB Data From Spotify and Genius APIs

# %% [markdown]
# Based on Vastava's notebook: <br>
# https://github.com/vastava/data-science-projects/blob/master/spotify-genre-classifier/get-spotify-data.ipynb

# %% [markdown]
# ## Setup and Library Imports

# %%
# Install spotipy and genius libraries
# !pip install spotipy -q
# !pip install lyricsgenius -q

# %%
import re
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import Counter
from statsmodels.stats.weightstats import ztest as ztest

# %%
# Display entire dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import lyricsgenius as lg

# %% [markdown]
# ## FOB DataFrame– Spotify Features and Genius Lyrics

# %%
# Spotipy-specific variables
cid = 'Your Client ID here'
secret = 'Your Client secret here'
user = 'Your Client user name here'
scope = 'user-library-read playlist-modify-public playlist-read-private'
redirect_uri = 'http://google.com'

client_credentials_manager = SpotifyClientCredentials(client_id = cid, client_secret = secret) 
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Genius-specific variables
genius_access_token = 'Your Genius access token here'
genius_obj = lg.Genius(genius_access_token)

# %% [markdown]
# ### Playlist Info
# Link: https://open.spotify.com/playlist/0ubKnC9ctDVxlGbF5jICvq?si=6ee6b776aaf943de <br>
#
# Currently including:
# - All FOB Songs on Spotify
# - Bonus tracks
# - Covers
# - Both studio versions of "Calm Before the Storm"
# - FOB Features, such as "I've Been Waiting" and "One and Only"<br>
#
# Currently not including:
# - remixes, including AB/AP remix album
# - live versions of songs whose studio versions are already included
# - acoustic versions of songs whose main studio versions are already included
# - Solo work after the hiatus
# - FOB songs which aren't on Spotify ("Pavlove")
#
# Classification of songs:
# - Class 0: pre-hiatus and Class 1: post-hiatus
# - Songs are classified by release date, not writing date
#     - Although "Light Em Up" and "Lake Effect Kid" were written pre-hiatus, they will be classified as post-hiatus

# %%
def get_features(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id)
    songs = results['items']
    
    while results['next']:
        results = sp.next(results)
        songs.extend(results['items'])    
    
    ids = []
    names = []
    dates = []
    
    for i in range(len(songs)):
        if songs[i]['track'] and songs[i]['track']['id'] != None:
            names.append(songs[i]['track']['name'])
            ids.append(songs[i]['track']['id'])
            dates.append(songs[i]['track']['album']['release_date'])
    ids = list(filter(None, ids))
    
    print(f'Found {len(ids)} songs.')
    
    features = [] 
    for id_idx, id_val in enumerate(ids):
        print(f'  Processing song #{id_idx+1}: {names[id_idx]}                                                ', end = '\r')
        audio_features = sp.audio_features(id_val)
        
        for index, feature in enumerate(audio_features):
            features.append(feature)
            
    features = list(filter(None, features))
    print(f'\r\nFinished processing {len(ids)} songs.')
    df = pd.DataFrame(features)
    df['title'] = names
    df['release_date'] = dates
    return df

# %%
fob_songs = get_features('shiffytali', '0ubKnC9ctDVxlGbF5jICvq')
# Out:
# Found 141 songs.
#   Processing song #141: Stayin out All Night - Boys of Zummer Remix                                                (feat. Missy Elliott)
# Finished processing 141 songs.

# %% [markdown]
# ### RegEx Setup
# - Goal: eliminate useless bracketed information from lyrics
# - Use a lot of | (or) operators because brackets can occur once in beginning, once at end, or twice!
#     - Last two pipes account for lyrics that have a bracket in the middle

# %%
def get_lyrics(song_list, artist):
    total_words = []
    unique_words = []
    pattern = r'(\[?([\w\-]+)\])|(\[([\w\-]+)\]?)|(\[([\w\-]+)\])|.*\[.*]?|.*\[?.*]'
    
    for idx, song in enumerate(song_list):
        lyrics = genius_obj.search_song(title = song, artist = artist).lyrics
        # Substitute any useless information with an empty string
        lyrics = re.sub(pattern, '', lyrics)
        count = Counter(lyrics.split())
        
        total = sum(count.values())
        unique = len(count)
        total_words.append(total)
        unique_words.append(unique)
    
    print('Processed all songs')    
    return total_words, unique_words

# %%
# Note titles that confuse the get_lyrics function
manually = {78: 'Beat It', 115: 'From Now On We Are Enemies',
            116: 'Yule Shoot Your Eye Out', 132: "I Wan'na Be Like You (The Monkey Song)",
            139: 'Ghostbusters (I’m Not Afraid)'}

# Replace with titles that will work with the get_lyrics function
for idx, title in manually.items():
    fob_songs.at[idx, 'title'] = title

# %%
fob_songs['total_words'], fob_songs['unique_words'] = get_lyrics(fob_songs['title'], 'Fall Out Boy')
# Out:
# Searching for "Honorable Mention" by Fall Out Boy...
# Done.
# Searching for "Calm Before the Storm" by Fall Out Boy...
# Done.
# Searching for "Switchblades and Infidelity" by Fall Out Boy...
# Done.
# Searching for "Pretty In Punk" by Fall Out Boy...
# Done.
# Searching for "Growing Up" by Fall Out Boy...
# Done.
# Searching for "The World’s Not Waiting (For Five Tired Boys In A Broken Down Van)" by Fall Out Boy...
# Done.
# Searching for "Short, Fast, And Loud" by Fall Out Boy...
# Done.
# Searching for "Moving Pictures" by Fall Out Boy...
# Done.
# Searching for "Parker Lewis Can't Lose (But I'm Gonna Give It My Best Shot)" by Fall Out Boy...
# Done.
# Searching for "Tell That Mick He Just Made My List of Things to Do Today" by Fall Out Boy...
# Done.
# Searching for "Dead on Arrival" by Fall Out Boy...
# Done.
# Searching for "Grand Theft Autumn / Where Is Your Boy" by Fall Out Boy...
# Done.
# Searching for "Saturday" by Fall Out Boy...
# Done.
# Searching for "Homesick at Space Camp" by Fall Out Boy...
# Done.
# Searching for "Sending Postcards From a Plane Crash (Wish You Were Here)" by Fall Out Boy...
# Done.
# Searching for "Chicago Is So Two Years Ago" by Fall Out Boy...
# Done.
# Searching for "The Pros and Cons of Breathing" by Fall Out Boy...
# Done.
# Searching for "Grenade Jumper" by Fall Out Boy...
# Done.
# Searching for "Calm Before the Storm" by Fall Out Boy...
# Done.
# Searching for "Reinventing the Wheel to Run Myself Over" by Fall Out Boy...
# Done.
# Searching for "The Patron Saint of Liars and Fakes" by Fall Out Boy...
# Done.
# Searching for "Our Lawyer Made Us Change The Name Of This Song So We Wouldn't Get Sued" by Fall Out Boy...
# Done.
# Searching for "Of All The Gin Joints In All The World" by Fall Out Boy...
# Done.
# Searching for "Dance, Dance" by Fall Out Boy...
# Done.
# Searching for "Sugar, We're Goin Down" by Fall Out Boy...
# Done.
# Searching for "Nobody Puts Baby In The Corner" by Fall Out Boy...
# Done.
# Searching for "I've Got A Dark Alley And A Bad Idea That Says You Should Shut Your Mouth (Summer Song)" by Fall Out Boy...
# Done.
# Searching for "7 Minutes In Heaven (Atavan Halen)" by Fall Out Boy...
# Done.
# Searching for "Sophomore Slump Or Comeback Of The Year" by Fall Out Boy...
# Done.
# Searching for "Champagne For My Real Friends, Real Pain For My Sham Friends" by Fall Out Boy...
# Done.
# Searching for "Saturday Night's Alright For Fighting" by Fall Out Boy...
# Done.
# Searching for "Lake Effect Kid" by Fall Out Boy...
# Done.
# Searching for "City In A Garden" by Fall Out Boy...
# Done.
# Searching for "Super Fade" by Fall Out Boy...
# Done.
# Searching for "Back to Earth (feat. Fall Out Boy)" by Fall Out Boy...
# Done.
# Searching for "We Were Doomed From The Start (The King Is Dead)" by Fall Out Boy...
# Done.
# Searching for "Art Of Keeping Up Disappearances" by Fall Out Boy...
# Done.
# Searching for "Hot To The Touch, Cold On The Inside" by Fall Out Boy...
# Done.
# Searching for "Love, Sex, Death" by Fall Out Boy...
# Done.
# Searching for "Eternal Summer" by Fall Out Boy...
# Done.
# Searching for "Demigods" by Fall Out Boy...
# Done.
# Searching for "American Made" by Fall Out Boy...
# Done.
# Searching for "Caffeine Cold" by Fall Out Boy...
# Done.
# Searching for "Roxanne" by Fall Out Boy...
# Done.
# Searching for "I Wanna Dance With Somebody (Who Loves Me) - Recorded at Spotify Studios NYC" by Fall Out Boy...
# Done.
# Searching for "I Wan'na Be Like You (The Monkey Song)" by Fall Out Boy...
# Done.
# Searching for "My Heart Is the Worst Kind of Weapon" by Fall Out Boy...
# Done.
# Searching for "It's Not a Side Effect of the Cocaine, I Am Thinking It Must Be Love" by Fall Out Boy...
# Done.
# Searching for "Start Today" by Fall Out Boy...
# Done.
# Searching for "One and Only" by Fall Out Boy...
# Done.
# Searching for "Love Will Tear Us Apart" by Fall Out Boy...
# Done.
# Searching for "Roxanne" by Fall Out Boy...
# Done.
# Searching for "Ghostbusters (I’m Not Afraid)" by Fall Out Boy...
# Done.
# Searching for "Stayin out All Night - Boys of Zummer Remix" by Fall Out Boy...
# Done.
# Processed all songs

# %%
fob_songs.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.384   0.969    5    -3.903     1       0.0985       0.00236
# 1         0.338   0.919    9    -5.538     1       0.3160       0.00391
# 2         0.374   0.990   11    -4.092     1       0.3800       0.00673
# 3         0.430   0.963    9    -4.803     1       0.1610       0.00347
# 4         0.291   0.971    0    -4.066     1       0.3010       0.00926
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000     0.277    0.374  103.858  audio_features
# 1          0.000251     0.307    0.464  173.643  audio_features
# 2          0.000003     0.250    0.336  135.163  audio_features
# 3          0.000000     0.298    0.268  125.773  audio_features
# 4          0.000000     0.287    0.408  149.928  audio_features
#
#                        id                                   uri  \
# 0  5fWwfsMUyLeApOAdIieGiX  spotify:track:5fWwfsMUyLeApOAdIieGiX
# 1  4kTbEgPxqeBz1wVeXcyKJy  spotify:track:4kTbEgPxqeBz1wVeXcyKJy
# 2  1gVJSRoWcnlDFQ472PSUaS  spotify:track:1gVJSRoWcnlDFQ472PSUaS
# 3  1ZcR4oKoZn7HHzpNsT40Nc  spotify:track:1ZcR4oKoZn7HHzpNsT40Nc
# 4  1SWB4y4XIjmesBR5Nn2qBJ  spotify:track:1SWB4y4XIjmesBR5Nn2qBJ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5fWwfsMUyLeA...
# 1  https://api.spotify.com/v1/tracks/4kTbEgPxqeBz...
# 2  https://api.spotify.com/v1/tracks/1gVJSRoWcnlD...
# 3  https://api.spotify.com/v1/tracks/1ZcR4oKoZn7H...
# 4  https://api.spotify.com/v1/tracks/1SWB4y4XIjme...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5fWw...       205867
# 1  https://api.spotify.com/v1/audio-analysis/4kTb...       283573
# 2  https://api.spotify.com/v1/audio-analysis/1gVJ...       194573
# 3  https://api.spotify.com/v1/audio-analysis/1ZcR...       217253
# 4  https://api.spotify.com/v1/audio-analysis/1SWB...       168973
#
#    time_signature                        title release_date  total_words  \
# 0               4            Honorable Mention   2003-03-25          201
# 1               4        Calm Before the Storm   2003-03-25          289
# 2               4  Switchblades and Infidelity   2003-03-25          165
# 3               4               Pretty In Punk   2003-03-25          249
# 4               3                   Growing Up   2003-03-25          174
#
#    unique_words
# 0            74
# 1           141
# 2            45
# 3            85
# 4            94

# %%
fob_songs.to_csv('data/raw/FOB_songs_raw.csv')

# %% [markdown]
# ## Data Cleaning and Validation

# %%
# Remove irrelevant columns
fob_songs = fob_songs.drop(labels = ['type','id', 'uri', 'track_href', 'analysis_url'], axis = 'columns')

# %%
# Move title column to first index
first_column = fob_songs.pop('title')
fob_songs.insert(0, 'title', first_column)

# %%
# Replace duration in ms with duration in minutes
fob_songs['duration_min'] = round((fob_songs['duration_ms'] / 60000), 2)
fob_songs = fob_songs.drop(['duration_ms'], axis = 1)

# %% [markdown]
# ### Clarification on Duration Column:
# The duration_min column does not show minutes.seconds. <br>
# For example, the first song in this list is Honorable Mention, which is 3 minutes and 25 seconds. My dataframe value for Honorable Mention in the duration_min column is 3.43 because 43/60 = ~25 <br>
# This value is displayed as a <i>fraction of a minute</i>, not as a count of seconds

# %%
fob_songs.to_csv('data/interim/FOB_songs_interim.csv')

# %% [markdown]
# ## Target Variable

# %%
fob_songs['class'] = 'pre-hiatus' # set default value as pre-hiatus

# Designate post-hiatus songs
for idx, date in enumerate(fob_songs['release_date']):
    year = int(date[:4])
    if (year == 1973) or (year > 2009):
        # Accounts for Elton John cover labeled as 1973 but recorded in post-hiatus era
        fob_songs.at[idx, 'class'] = 'post-hiatus'

# %%
fob_songs.head()
# Out:
#                          title  danceability  energy  key  loudness  mode  \
# 0            Honorable Mention         0.384   0.969    5    -3.903     1
# 1        Calm Before the Storm         0.338   0.919    9    -5.538     1
# 2  Switchblades and Infidelity         0.374   0.990   11    -4.092     1
# 3               Pretty In Punk         0.430   0.963    9    -4.803     1
# 4                   Growing Up         0.291   0.971    0    -4.066     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0985       0.00236          0.000000     0.277    0.374  103.858
# 1       0.3160       0.00391          0.000251     0.307    0.464  173.643
# 2       0.3800       0.00673          0.000003     0.250    0.336  135.163
# 3       0.1610       0.00347          0.000000     0.298    0.268  125.773
# 4       0.3010       0.00926          0.000000     0.287    0.408  149.928
#
#    time_signature release_date  total_words  unique_words  duration_min  \
# 0               4   2003-03-25          201            74          3.43
# 1               4   2003-03-25          289           141          4.73
# 2               4   2003-03-25          165            45          3.24
# 3               4   2003-03-25          249            85          3.62
# 4               3   2003-03-25          174            94          2.82
#
#         class
# 0  pre-hiatus
# 1  pre-hiatus
# 2  pre-hiatus
# 3  pre-hiatus
# 4  pre-hiatus

# %% [markdown]
# ### Convert processed song data to csv

# %%
fob_songs.to_csv('data/processed/FOB_songs_processed.csv')
